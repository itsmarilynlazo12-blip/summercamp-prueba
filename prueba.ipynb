# %% [markdown]
# <a href="https://colab.research.google.com/github/itsmarilynlazo12-blip/summercamp-prueba/blob/main/prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Olivia Rodrigo")
# Out:
# Olivia Rodrigo

# %%
jugador ="Rosalina"
print(jugador,"Ha usado un lindo vestido")
jugador2 = "Peach"
print(jugador2,"se ha caido del escenario")
# Out:
# Rosalina Ha usado un lindo vestido
# Peach se ha caido del escenario
