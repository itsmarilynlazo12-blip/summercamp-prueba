# %% [markdown]
# <a href="https://colab.research.google.com/github/itsmarilynlazo12-blip/summercamp-prueba/blob/main/Dia_2_Pintando_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sqlite3
import seaborn as sns
import matplotlib.pyplot as plt

connexion = sqlite3.connect("torneo_smash.db")
df_original = pd.read_csv("smash_dataset_clean.csv", encoding="latin")
df_original.to.sql("combates", conexion, if_exist="replace", index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_13017/2636484137.py in <cell line: 0>()
#       6 connexion = sqlite3.connect("torneo_smash.db")
#       7 df_original = pd.read_csv("smash_dataset_clean.csv", encoding="latin")
# ----> 8 df_original.to.sql("combates", conexion, if_exist="replace", index=False)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'to'
