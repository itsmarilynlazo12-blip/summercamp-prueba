# %% [markdown]
# <a href="https://colab.research.google.com/github/itsmarilynlazo12-blip/summercamp-prueba/blob/main/Streamlitbasic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Instalando los mods en nuestra mesa de crafteo
# !pip install streamlit -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 47.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 83.3 MB/s eta 0:00:00

# %%
#Escribiendo nuestra aplicación
# %%writefile mi_app.py
import streamlit as st
import pandas as pd
import plotly.express as px

# Hacemos que la página sea más ancha para que el gráfico sea mas grande
st.set_page_config(layout="wide")

st.title("💎 Mi mapa 3D de cantantes")
st.write("Haz clic sostenido para girar la cueva y usa la rueda del ratón para hacer zoom")

# Coordenadas X, Y, Z como en minecraft
datos = pd.DataFrame({
    "Artista": ["Beyonce", "Harry Styles", "Taylor Swift", "Liam Payne", "Ariana Grande", "Olivia Rodrigo"],
    "Capa_X": [10, 25, 5, 30, 15, 8],
    "Capa_Z": [15, 5, 20, 10, 25, 2],
    "Profundidad_Y": [50, 35, 15, -10, -30, -55], # El diamante está en lo más profundo
    "Experiencia": [10, 20, 30, 40, 50, 100],     # Esto hará que la burbuja sea más grande
})

# Creando el gráfico 3D interactivo
fig = px.scatter_3d(
    datos,
    x='Capa_X',
    y='Capa_Z',
    z='Profundidad_Y',
    color='Artista',
    size='Experiencia',
    hover_name='Artista',
    # Le damos los colores reales a los minerales
    color_discrete_map={
        "Beyonce": "#555555",
        "Harry Styles": "#5762FF",
        "Taylor Swift": "#FF5787",
        "Liam Payne": "#3E6C87",
        "Ariana Grande": "#FFCCF5",
        "Diamante": "#A600FF"
    }
)

# Apagamos las luces para que parezca una cueva oscura
fig.update_layout(
    template="plotly_dark",
    scene=dict(bgcolor="#111111"),
    margin=dict(l=0, r=0, b=0, t=0)
)

# Mostramos el gráfico en Streamlit
st.plotly_chart(fig, use_container_width=True)
# Out:
# Overwriting mi_app.py

# %%
# CELDA 3: ¡El Portal Definitivo (Descarga + Cazador de Zombies)!

# Descargamos el creador de portales
# !wget -q -O cloudflared https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# !chmod +x cloudflared

# Cerramos procesos viejos que se quedaron trabados
# !pkill -f streamlit
# !pkill -f cloudflared
import time
time.sleep(2)

# Corremos nuestra app de Streamlit
# !streamlit run mi_app.py &>/dev/null &

# Encendemos el portal de Cloudflare
# !nohup ./cloudflared tunnel --url http://localhost:8501 > portal.log 2>&1 &

# Creamos el enlace
print("⛏️ Construyendo un portal súper estable... (espera 8 segundos)")
time.sleep(8)
print("\n ¡PORTAL LISTO Y SEGURO! Haz clic en el enlace azul:")
# !grep -o 'https://.*\.trycloudflare.com' portal.log
# Out:
# cloudflared: Text file busy
# ⛏️ Construyendo un portal súper estable... (espera 8 segundos)
#
#  ¡PORTAL LISTO Y SEGURO! Haz clic en el enlace azul:
# https://consist-cancer-procedure-footwear.trycloudflare.com
